# %% [markdown]
# # 6.1 비지도학습
#
# ### 비지도학습이란?
# - 정답 라벨이 없는 데이터를 비슷한 특징끼리 군집화 하여 새로운 데이터에 대한 결과를 예측하는 방법
# - 정답(label) 없이 데이터를 학습합니다. 이것의 목적은 인간의 개입이 없는 데이터를 스스로 학습하여 그 속의 패턴(pattern) 또는 각 데이터 간의 유사도(similarity)를 학습
# - 데이터 자체가 부족하거나 훈련 데이터를 수집하기에는 비용이 너무 높은 등의 이유로 출력에 대해 알 수 없거나 활용할 수 없을 때 주로 사용
# #### <종류>
# - Clustering
# - K Means
# - Density Estimation
# - Exception Maximization
# - Pazen Window
# - DBSCAN
# #### <예시>
# - 여러 과일의 사진이 있고 이 사진이 어떤 과일의 사진인지 정답이 없는 데이터에 대해 색깔이 무엇인지, 모양이 어떠한지 등에 대한 피처를 토대로 바나나다, 사과다 등으로 군집화 하는 것
# - 새로 출시할 상품 유형에 맞는 타겟 시장을 정의

# %% [markdown]
# ## 군집알고리즘
#
# ### 군집이란(Clustering):
# 데이터를 비슷한 것끼리 묶어 클러스터(Cluster)라는 그룹으로 나누는 작업
# #### <군집의 목표>
# - 군집 알고리즘의 목표는 한 클러스터 안의 데이터 포인트끼리는 매우 비슷하고, 다른 클러스터의 데이터 포인트와는 구분되도록 데이터를 나누는 것
# - 유사성(Similarity)을 비교하여 데이터를 나눈다
#
#
#
# ### axis
# - axis = 0
# - axis = 1
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.34.35.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.34.35.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.44.22.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.44.22.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.44.06.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.44.06.png)

# %% [markdown]
# # 6.2 k-means
# - 데이터를 K개의 군집(Cluster)으로 묶는(Clusting) 알고리즘
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.35.31.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.35.31.png)

# %% [markdown]
# ## K-means 알고리즘 원리
#
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.37.06.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.37.06.png)

# %% [markdown]
# > 블롣그에 과정이 잘 나와 있어서 링크를 남겨둔다. : https://velog.io/@jhlee508/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-K-%ED%8F%89%EA%B7%A0K-Means-%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98
#
#
# 1. 군집의 개수(K) 설정하기
# - 군집의 개수를 직접 설정해야 한다는 것은 K-means 알고리즘의 한계점 중에 하나
# - 군집의 개수 설정을 어떻게 하냐에 따라 결과가 크게 달라지고 터무니 없는 결과가 나올 수도 있다.
#
# <군집 개수를 설정하는 방법론>
# 1) Rule of thumb
# 2) Elbow Method
# - 이너셔의 변화를 관찰하여 최적의 클러스터 개수를 찾는 방법
# - 클러스터 개수를 늘렸을 때 centroid 간의 평균 거리가 더 이상 많이 감소하지 않는 경우의 K를 선택하는 방법.
# - 개수가 늘 때마다 평균값이 급격히 감소하는데 적절한 K가 발견되면 매우 천천히 감소한다.
# - 그래프 상에서 이 부분이 팔꿈치랑 닮아서 엘보우 기법이라고 한다.
# - 참고로, 클러스터 개수가 적으면 centroid 간의 거리가 매우 커지며, 적절한 개수이면 거리가 점점 짧아진다. 개수가 많으면 평균 거리가 매우 조금씩 줄어든다.
#
# <코드구현>
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.20.47.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.20.47.png)
#
#
# 3) 정보 기준 접근법 (Information Criterion Approach)

# %% [markdown]
# 2. 초기 중심점 설정하기
# - K개의 초기 중심점(Center of Cluster, Centroid)을 설정하는 단계
# - 초기 중심점으로 어떤 값을 선택하는가에 따라 성능이 크게 달라진다.
#
# <초기값을 설정하는 방법론>
# 1) Randomly select
# 2) Manually assign
# 3) K-means++

# %% [markdown]
# 3. 데이터를 군집에 할당(배정)하기
# - 거리 상 가장 가까운 군집(중심점)으로 주어진 모든 데이터를 할당 또는 배정

# %% [markdown]
# 4) 중심점 재설정(갱신)하기
# - 군집의 중심점(Centroid)을 그 군집의 속하는 데이터들의 가장 중간(평균)에 위치한 지점으로 재설정
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.48.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.48.55.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.50.24.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.50.24.png)

# %% [markdown]
#  5) 데이터를 군집에 재할당(배정)하기
#  - 과정 3에서 했던 방법과 똑같이 시행하며, 더 이상 중심점의 이동이 없을 때까지 과정 4와 과정 5를 반복

# %% [markdown]
# # 6. 3 차원 축소 : 주성분 분석 PCA

# %% [markdown]
# 1. 차원의 의미
# - 다차원 배열 : 축의 개수
# - 1차원 배열 : 벡터일 경우 원소의 개수
#
#
# 2. PCA란
# - dimensionality reduction (차원 축소)에 쓰이는 기법으로, 머신러닝, 데이터마이닝, 통계 분석, 노이즈 제거 등 다양한 분야에서 쓰임
#
# - 주성분을 찾아주는 방법 , 즉 데이터의 분포 특성을 2개의 벡터로 가장 잘 설명하는 방법을 찾는 것
# - 제 1 주성분 벡터는 데이터 분포의 분산이 가장 큰 방향을 나타냄
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.32.49.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.32.49.png)
#
# - a1의 방향과 크기, 그리고 a2의 방향과 크기를 알면 이 데이터 분포가 어떤 형태인지를 가장 단순하면서도 효과적으로 파악 가능
# - PCA는 2차원 데이터 집합에 대해 PCA를 수행하면 2개의 서로 수직인 주성분 벡터를 반환

# %% [markdown]
# > 설명이 잘 되어있는 블로그 링크를 남긴다. : https://ddongwon.tistory.com/114

# %% [markdown]
# - 3차원 점들에 대해 PCA를 수행하면 3개의 서로 수직인 주성분 벡터들을 반환
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.34.11.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.34.11.png)
